# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("overview_2021-07-04 (2).csv")
df.head(10)
# Out:
#     areaCode        areaName  areaType        date  newCasesByPublishDate
# 0  K02000001  United Kingdom  overview  2021-07-04                  24248
# 1  K02000001  United Kingdom  overview  2021-07-03                  24885
# 2  K02000001  United Kingdom  overview  2021-07-02                  27125
# 3  K02000001  United Kingdom  overview  2021-07-01                  27989
# 4  K02000001  United Kingdom  overview  2021-06-30                  26068
# 5  K02000001  United Kingdom  overview  2021-06-29                  20479
# 6  K02000001  United Kingdom  overview  2021-06-28                  22868
# 7  K02000001  United Kingdom  overview  2021-06-27                  14876
# 8  K02000001  United Kingdom  overview  2021-06-26                  18270
# 9  K02000001  United Kingdom  overview  2021-06-25                  15810

# %%
df = df.drop(['areaCode'], axis=1)
df = df.drop(['areaType'], axis=1)
df = df.drop(['areaName'], axis=1)
df
# Out:
#            date  newCasesByPublishDate
# 0    2021-07-04                  24248
# 1    2021-07-03                  24885
# 2    2021-07-02                  27125
# 3    2021-07-01                  27989
# 4    2021-06-30                  26068
# ..          ...                    ...
# 516  2020-02-04                      0
# 517  2020-02-03                      0
# 518  2020-02-02                      0
# 519  2020-02-01                      0
# 520  2020-01-31                      2
#
# [521 rows x 2 columns]

# %%
df = df.sort_values(by=['date'])

# %%
for i in range(0,df.shape[0]-13):
    df.loc[df.index[i+13],'SMA_14'] = np.round(((df.iloc[i,1]+ df.iloc[i+1,1] +df.iloc[i+2,1]+df.iloc[i+3,1]+ df.iloc[i+4,1]+ df.iloc[i+5,1]+ df.iloc[i+6,1]+ df.iloc[i+7,1]+ df.iloc[i+8,1]+ df.iloc[i+9,1]+ df.iloc[i+10,1]+ df.iloc[i+11,1]+ df.iloc[i+12,1]+ df.iloc[i+13,1])/14),1)

# %%
df['pandas_SMA_14'] = df.iloc[:,1].rolling(window=14).mean()

# %%
plt.figure(figsize=[15,10])
plt.style.use('ggplot')
plt.grid(True)
plt.plot(df['date'], df['SMA_14'], label='Casi Giornalieri media mobile 14', linewidth=3, color = 'blue')
plt.xticks([0, 100, 200, 300, 400, 500], rotation=30)
plt.axis([0, 525, 0, 60000])
plt.xlabel('Giorni')
plt.ylabel('Casi Giornalieri')
plt.title("Casi Giornalieri UK", fontsize=20)
plt.legend(loc=2)
# Out:
# C:\Users\giuse\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1377: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\giuse\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:237: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# C:\Users\giuse\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:239: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
df2 = pd.read_csv("overview_2021-07-04 (1).csv")
df2.head(10)
# Out:
#     areaCode        areaName  areaType        date  covidOccupiedMVBeds
# 0  K02000001  United Kingdom  overview  2021-07-01                  300
# 1  K02000001  United Kingdom  overview  2021-06-30                  287
# 2  K02000001  United Kingdom  overview  2021-06-29                  283
# 3  K02000001  United Kingdom  overview  2021-06-28                  297
# 4  K02000001  United Kingdom  overview  2021-06-27                  263
# 5  K02000001  United Kingdom  overview  2021-06-26                  256
# 6  K02000001  United Kingdom  overview  2021-06-25                  257
# 7  K02000001  United Kingdom  overview  2021-06-24                  259
# 8  K02000001  United Kingdom  overview  2021-06-23                  246
# 9  K02000001  United Kingdom  overview  2021-06-22                  250

# %%
df2 = df2.drop(['areaCode'], axis=1)
df2 = df2.drop(['areaType'], axis=1)
df2 = df2.drop(['areaName'], axis=1)

# %%
df2
# Out:
#            date  covidOccupiedMVBeds
# 0    2021-07-01                  300
# 1    2021-06-30                  287
# 2    2021-06-29                  283
# 3    2021-06-28                  297
# 4    2021-06-27                  263
# ..          ...                  ...
# 451  2020-04-06                 2644
# 452  2020-04-05                 2469
# 453  2020-04-04                 2309
# 454  2020-04-03                 2120
# 455  2020-04-02                 1813
#
# [456 rows x 2 columns]

# %%
df2 = df2.sort_values(by=['date'])

# %%
df2
# Out:
#            date  covidOccupiedMVBeds
# 455  2020-04-02                 1813
# 454  2020-04-03                 2120
# 453  2020-04-04                 2309
# 452  2020-04-05                 2469
# 451  2020-04-06                 2644
# ..          ...                  ...
# 4    2021-06-27                  263
# 3    2021-06-28                  297
# 2    2021-06-29                  283
# 1    2021-06-30                  287
# 0    2021-07-01                  300
#
# [456 rows x 2 columns]

# %%
plt.figure(figsize=[15,10])
plt.style.use('ggplot')
plt.grid(True)
plt.plot(df2['date'], df2['covidOccupiedMVBeds'], label='Casi Giornalieri', linewidth=2, linestyle='--')
plt.xticks([0, 100, 200, 300, 400], rotation=30)
plt.axis([0, 460, 0, 5000])
plt.xlabel('Giorni')
plt.ylabel('Casi Giornalieri')
plt.title("Casi Giornalieri UK", fontsize=20)
plt.legend(loc=2)
# Out:
# C:\Users\giuse\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1377: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\giuse\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:237: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# C:\Users\giuse\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:239: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
df3 = df.drop(df.index[0:65])

# %%
df3
# Out:
#            date  newCasesByPublishDate   SMA_14  pandas_SMA_14
# 455  2020-04-05                   6199   3128.4    3128.428571
# 454  2020-04-06                   4143   3355.3    3355.285714
# 453  2020-04-07                   3888   3531.1    3531.071429
# 452  2020-04-08                   5865   3846.3    3846.285714
# 451  2020-04-09                   4675   4028.1    4028.142857
# ..          ...                    ...      ...            ...
# 4    2021-06-30                  26068  15325.4   15325.357143
# 3    2021-07-01                  27989  16538.4   16538.357143
# 2    2021-07-02                  27125  17727.6   17727.571429
# 1    2021-07-03                  24885  18767.9   18767.857143
# 0    2021-07-04                  24248  19836.7   19836.714286
#
# [456 rows x 4 columns]

# %%
fig, ax1 = plt.subplots()
fig.set_figheight(15)
fig.set_figwidth(15)
plt.style.use("ggplot")
plt.grid(False)

color = 'tab:red'
ax1.set_xlabel('Data')
ax1.set_ylabel('Casi', color=color)
ax1.plot(df3['date'], df3['SMA_14'], color=color, linewidth=4, label='Casi')
ax1.tick_params(axis='y', labelcolor=color)


ax2 = ax1.twinx() 

color = 'tab:blue'
ax2.set_ylabel('terapia intensiva', color=color) 
ax2.plot(df3['date'], df2['covidOccupiedMVBeds'], color=color, linewidth=4, label='Terapia intensiva')
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  
plt.xticks([0, 100, 200, 300, 400], rotation=30)
plt.axvspan(201.8, 202.5, color='green', alpha=0.5)
plt.axvspan(455.8, 456.2, color='purple', alpha=0.5)
plt.axhspan(300, 750, color='orange', alpha=0.5)
plt.title("Casi e Terapia Intensiva UK", fontsize=20)
plt.show()
# Out:
# C:\Users\giuse\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1377: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\giuse\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:237: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# C:\Users\giuse\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:239: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
